# %%
import pandas as pd
def admissions():
    data = {'name': [str(input("What is your name?: "))],
            'age': [int(input("How old are you?: "))],
            'department': [str(input("What department are you applying for? : "))]}
            
    print("What department are you applying for?: 1. Computer Science OR 2. Mass Communications")
    decision = int(input("Pick a department: "))
    if decision == 1:
            jamb = int(input("What is your jamb score?: "))
            credits = bool(input("Credits were made in 5 key subjects?:"))
            interview = bool(input("Interview was passed?: "))
            if jamb >= 230 and credits == True and interview == True:
                print("Congratulations! You are welcome to Computer Science Department ")
                df = pd.DataFrame(data)
                df.to_csv('admitted.csv')
            elif jamb >= 230 and credits == False and interview == True:
                print("Sorry you have not been given admission to Computer Science Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            elif jamb >= 230 and credits == False and interview == False:
                print("Sorry you have not been given admission to Computer Science Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            elif  jamb >= 230 and credits == True and interview == False:
                print("Sorry you have not been given admission to Computer Science Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            elif  jamb < 230 and credits == True and interview == False:
                print("Sorry you have not been given admission to Computer Science Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            elif  jamb < 230 and credits == False and interview == True:
                print("Sorry you have not been given admission to Computer Science Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            elif  jamb < 230 and credits == False and interview == False:
                print("Sorry you have not been given admission to Computer Science Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            elif  jamb < 230 and credits == True and interview == True:
                print("Sorry you have not been given admission to Computer Science Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            else:
                print("Invalid Input")
    elif decision == 2:
            jamb1 = int(input("What is your jamb score?: "))
            credits1 = bool(input("Credits were made in 5 key subjects?:"))
            interview1 = bool(input("Interview was passed?: "))
            if jamb1 >= 230 and credits1 == True and interview1 == True:
                print("Congratulations! You are welcome to Mass Communications Department ")
                df = pd.DataFrame(data)
                df.to_csv('admitted.csv')
            elif jamb1 >= 230 and credits1 == False and interview1 == True:
                print("Sorry you have not been given admission to Mass Communications Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            elif jamb1 >= 230 and credits1 == False and interview1 == False:
                print("Sorry you have not been given admission to Mass Communications Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            elif  jamb1 >= 230 and credits1 == True and interview1 == False:
                print("Sorry you have not been given admission to Computer Science Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            elif  jamb1 < 230 and credits1 == True and interview1 == False:
                print("Sorry you have not been given admission to Computer Science Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            elif  jamb1 < 230 and credits1 == False and interview1 == True:
                print("Sorry you have not been given admission to Computer Science Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            elif  jamb1 < 230 and credits1 == False and interview1 == False:
                print("Sorry you have not been given admission to Mass Communications Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            elif  jamb1 < 230 and credits1 == True and interview1 == True:
                print("Sorry you have not been given admission to Computer Science Department ")
                df = pd.DataFrame(data)
                df.to_csv('not-admitted.csv')
            else:
                print("Invalid Input")
                
print("PROGRAM FOR DEPARTMENT ADMISSIONS")
admissions()
# Out:
# PROGRAM FOR DEPARTMENT ADMISSIONS
# What is your name?: OBIEKWE KENE
# How old are you?: 17
# What department are you applying for? : COMPUTER SCIENCE
# What department are you applying for?: 1. Computer Science OR 2. Mass Communications
# Pick a department: 1
# What is your jamb score?: 286
# Credits were made in 5 key subjects?:True
# Interview was passed?: True
# Congratulations! You are welcome to Computer Science Department
